# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinab/VinaB/blob/main/CodeViaCollab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Coding via collab")
# Out:
# Coding via collab
